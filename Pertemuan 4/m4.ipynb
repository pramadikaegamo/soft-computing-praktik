# %%
pip install pyit2fls
# Out:
# ...
#   Using cached pyit2fls-0.7.9-py3-none-any.whl (21 kB)
# ...
#      ---------------------------------------- 7.2/7.2 MB 9.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 40.1/40.1 MB 6.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.6/14.6 MB 5.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 965.4/965.4 kB 6.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB 2.8 MB/s eta 0:00:00
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#      -------------------------------------- 164.1/164.1 kB 9.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.3/3.3 MB 6.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\LABKOM\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
# ...

# %%
from pyit2fls import zero_mf, singleton_mf, const_mf, tri_mf, ltri_mf, rtri_mf, trapezoid_mf, gaussian_mf
import matplotlib.pyplot as plt
from numpy import linspace

domain_ringan = linspace(0., 5, 1000)
domain_sedang = linspace(4, 10, 1000)
domain_berat = linspace(8, 14, 1000)
# mySet = T1FS(domain, trapezoid_mf, [4, 6, 8, 10, 1.0])
# mySet.plot()


trapezoid = trapezoid_mf(domain_sedang, [4, 6, 8, 10, 1.0])
ltri = tri_mf(domain_ringan, [0, 4, 5, 1.0])
rtri = tri_mf(domain_berat, [8, 10, 14, 1.0 ])

plt.figure()
plt.plot(domain_ringan, ltri, label="Ringan")
plt.plot(domain_sedang, trapezoid, label="Sedang")
plt.plot(domain_berat, rtri, label="Berat")
plt.grid(True)
plt.legend()
plt.xlabel("Berat Pakaian")
plt.ylabel("Membership function")
plt.savefig("M04_5200411193_Pramadika Egamo.png")
plt.show()

# %%
from pyit2fls import zero_mf, singleton_mf, const_mf, tri_mf, ltri_mf, rtri_mf, trapezoid_mf, gaussian_mf
import matplotlib.pyplot as plt
from numpy import linspace

domain_rendah = linspace(0., 60, 1000)
domain_tinggi = linspace(20, 100, 1000)
# mySet = T1FS(domain, trapezoid_mf, [4, 6, 8, 10, 1.0])
# mySet.plot()


tri = tri_mf(domain_rendah, [0, 20, 60, 1.0])
tri2 = tri_mf(domain_tinggi, [20, 60, 100, 1.0 ])

plt.figure()
plt.plot(domain_rendah, tri, label="Rendah")
plt.plot(domain_tinggi, tri2, label="Tinggi")
plt.grid(True)
plt.legend()
plt.xlabel("Intensitas Kotor")
plt.ylabel("Membership function")
plt.savefig("M04_5200411193_Pramadika Egamo.png")
plt.show()

# %%
from pyit2fls import zero_mf, singleton_mf, const_mf, tri_mf, ltri_mf, rtri_mf, trapezoid_mf, gaussian_mf
import matplotlib.pyplot as plt
from numpy import linspace
domain_cepat = linspace(0., 50, 1000)
domain_sedang = linspace(30, 100, 1000)
domain_lama = linspace(70, 120, 1000)
# mySet = T1FS(domain, trapezoid_mf, [4, 6, 8, 10, 1.0])
# mySet.plot()


tri = trapezoid_mf(domain_cepat, [-10, 0, 30, 50, 1.0])
trapezoid = trapezoid_mf(domain_sedang, [30, 50, 70, 100, 1.0])
tri2 = trapezoid_mf(domain_lama, [70, 100, 120, 140, 1.0 ])

plt.figure()
plt.plot(domain_cepat, tri, label="Cepat")
plt.plot(domain_sedang, trapezoid, label="Sedang")
plt.plot(domain_lama, tri2, label="Lama")
plt.grid(True)
plt.legend()
plt.xlabel("Durasi Cuci")
plt.ylabel("Membership function")
plt.savefig("M04_5200411193_Pramadika Egamo.png")
plt.show()
